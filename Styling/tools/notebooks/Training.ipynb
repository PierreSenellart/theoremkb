# %%
import pandas as pd
import numpy as np
import os, sys, pickle

sys.path.append("..")
from config import DATA_PATH

# %%
with open(f'{DATA_PATH}/features-line.pkl', "rb") as f:
    dataset = pickle.load(f)

# %%
print(dataset.columns)
count = dataset['kind'].value_counts()
n_text   = count['O']
n_theorems = sum(x for k,x in count.items() if 'Theorem' in k)
n_begin_theorems = count['B-Theorem']
n_result = sum(x for k,x in count.items() if k != 'O')
print(n_text, n_result, n_theorems, n_begin_theorems)
print(count)
papers = dataset['from'].unique()
print(len(papers))
dataset.describe()
# Out:
# Index(['delta_v', 'delta_h', 'mean_length', 'mean_math', 'mean_italic',
#        'mean_fontsize', 'first_proof', 'first_definition', 'first_theorem',
#        'first_lemma', 'first_proposition', 'first_capital', 'first_bold',
#        'text', 'kind', 'result', 'from'],
#       dtype='object')
# 3095147 231766 87660 16680
# O                3095147
# I-Theorem          70980
# I-Lemma            60494
# I-Definition       45580
# B-Theorem          16680
# I-Proposition      14220
# B-Lemma            12705
# B-Definition        7703
# B-Proposition       3404
# Name: kind, dtype: int64
# 2642
#             delta_v       delta_h   mean_length     mean_math   mean_italic  \
# count  3.326913e+06  3.326913e+06  3.326913e+06  3.326913e+06  3.326913e+06
# mean   4.547664e+01  2.709534e+01  3.391052e+00  2.592986e-01  4.045393e-02
# std    1.866049e+04  7.329088e+01  2.067119e+00  3.331603e-01  1.520114e-01
# min    0.000000e+00 -3.191071e+03  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.714286e+00  0.000000e+00  0.000000e+00
# 50%    3.217800e+00  0.000000e+00  3.222222e+00  1.000000e-01  0.000000e+00
# 75%    5.893000e+00  9.962000e+00  4.647059e+00  4.333333e-01  0.000000e+00
# max    9.999999e+06  7.026070e+02  1.380000e+02  1.000000e+00  1.000000e+00
#
#        mean_fontsize         result
# count   3.326913e+06  231766.000000
# mean    9.972857e+00      20.289236
# std     1.588363e+00      24.001690
# min     0.000000e+00       1.000000
# 25%     9.536000e+00       6.000000
# 50%     1.008717e+01      13.000000
# 75%     1.090900e+01      26.000000
# max     1.494400e+02     253.000000

# %%
prediction_mode = "theorem-only"

def is_theorem(x):
    return (x.kind == "I-Theorem") | (x.kind == "B-Theorem")

def sample_dataset(dataset):
    n_sample = n_theorems # number of results.
    
    n_sample_per_theorem = 4 * n_sample // n_begin_theorems
    print("Samples per theorem:", n_sample_per_theorem)
    
    near_theorem = is_theorem(dataset).rolling(n_sample_per_theorem, min_periods=1, center=True).max()
    print(dataset[near_theorem == 1.])
    return dataset[near_theorem == 1.]


filtered_dataset = sample_dataset(dataset)
    
if prediction_mode == "theorem-only":
    replacement = {}
    
    for k in ['Theorem']:
        for b in ['I', 'B']:
            replacement[f"{b}-{k}"] = b
    for k in ['Lemma', 'Definition', 'Proposition']:
        for b in ['I', 'B']:
            replacement[f"{b}-{k}"] = 'O'
    
        
        
filtered_dataset.replace(replacement, inplace=True)
filtered_dataset['kind'].value_counts()
# Out:
# Samples per theorem: 21
#          delta_v  delta_h  mean_length  mean_math  mean_italic  mean_fontsize  \
# 65        0.0000  272.637     1.700000   0.500000     0.000000      10.027300
# 66        1.3269    0.000     6.000000   0.000000     0.250000      10.909000
# 67        3.9817    0.000     4.062500   0.125000     0.250000      10.725313
# 68        2.9159    0.000     5.307692   0.000000     0.076923      10.909000
# 69        2.0297    0.000     6.250000   0.250000     0.500000      10.174250
# 70        0.0000  120.893     1.400000   0.400000     0.000000       9.733400
# 71        0.0000  157.197     2.600000   0.200000     0.000000      10.517133
# 72        6.5592    0.000     7.100000   0.000000     0.000000      10.909000
# 73        3.9817    0.000     3.833333   0.166667     0.000000      10.909000
# 74        3.9817    0.000     2.000000   0.000000     0.000000      10.909000
# 75       10.1360    0.000     2.800000   0.333333     0.333333      10.517133
# 76        0.0000  270.330     1.500000   0.250000     0.000000       9.439500
# 77        0.0000  300.211     1.666667   0.333333     0.000000       9.929333
# 78        9.9602   16.364     4.117647   0.117647     0.058824      10.909000
# 79        2.0307    0.000     3.684211   0.421053     0.000000      10.754316
# 80        5.9337    0.000     3.470588   0.117647     0.000000      10.909000
# 81       11.4097    0.000     1.714286   0.285714     0.000000      10.489143
# 82        0.0000  219.192     3.000000   0.000000     0.000000      10.909000
# 83       13.9077    0.000     4.000000   0.117647     0.000000      10.909000
# 84        3.9817    0.000     4.125000   0.125000     0.000000      10.909000
# 85        3.9827    0.000     4.333333   0.066667     0.200000      10.713067
# 86        8.6069    0.000     2.500000   0.300000     0.350000      10.468150
# 87        0.0000  316.885     1.666667   0.333333     0.000000       9.929333
# 88        9.9602   16.364     5.500000   0.000000     0.000000      10.909000
# 89        2.0307    0.000     3.666667   0.333333     0.000000      10.745722
# 90        3.9817    0.000     3.000000   0.454545     0.000000      10.641818
# 91        4.8679    0.000     2.913043   0.260870     0.000000      10.525652
# 92       18.4869    0.000     1.000000   0.000000     0.000000      11.955000
# 93       96.1074    0.000     3.090909   0.318182     0.000000      10.641818
# 94        4.8145    0.000     4.571429   0.071429     0.000000      10.909000
# ...          ...      ...          ...        ...          ...            ...
# 3326544   0.0000    0.000     1.000000   1.000000     0.000000       6.974000
# 3326545   0.0000    0.000     1.250000   0.583333     0.000000       9.464833
# 3326546   0.7526    0.000     3.000000   1.000000     0.000000       6.974000
# 3326547   0.0000    0.499     1.000000   0.000000     0.000000       9.963000
# 3326548   4.8358    0.000     1.000000   1.000000     0.000000       9.963000
# 3326549   0.0000    0.000     1.000000   1.000000     0.000000       6.974000
# 3326550   4.2970    0.000     1.500000   0.625000     0.000000       9.215750
# 3326551   4.1436    0.000     3.000000   1.000000     0.000000       6.974000
# 3326552   5.9650    0.000     4.583333   0.000000     0.000000       9.963000
# 3326553   9.7528    0.000     3.571429   0.190476     0.666667       9.963000
# 3326554   2.6600    0.000     2.857143   0.428571     0.464286       9.749500
# 3326555   2.3026    0.000     4.000000   0.000000     1.000000       9.963000
# 3326556  11.6829    0.000     3.000000   0.000000     0.000000       9.963000
# 3326557   0.0000  173.341     1.000000   1.000000     0.000000       9.963000
# 3326558   0.0000  193.800     3.333333   0.333333     0.000000       9.963000
# 3326559   3.9988  216.574     1.000000   0.500000     0.000000       8.468500
# 3326560   5.2268    0.000     3.000000   0.000000     1.000000       9.963000
# 3326561   2.1718  162.292     3.000000   0.500000     0.000000       8.468500
# 3326562   0.0000    0.000     1.000000   1.000000     0.000000       6.974000
# 3326563   0.0000    0.000     1.166667   0.750000     0.000000       9.464833
# 3326564   8.8676    0.000     5.200000   0.000000     0.133333       9.963000
# 3326565   3.2178    0.000     6.000000   0.000000     0.000000       9.963000
# 3326566   3.2188    0.000     5.333333   0.000000     0.000000       9.963000
# 3326567   3.2178    0.000     5.062500   0.000000     0.062500       9.963000
# 3326568   3.2178    0.000     4.666667   0.055556     0.000000       9.963000
# 3326569   3.2178    0.000     4.444444   0.000000     0.000000       9.963000
# 3326570   3.2178    0.000     4.764706   0.058824     0.000000       9.963000
# 3326571   3.2178    0.000    13.000000   0.000000     0.000000       9.963000
# 3326572  15.1738    0.000     4.277778   0.000000     0.111111       9.963000
# 3326573   3.2178    0.000     5.928571   0.000000     0.071429       9.963000
#
#          first_proof  first_definition  first_theorem  first_lemma  \
# 65             False             False          False        False
# 66             False             False          False        False
# 67             False             False          False        False
# 68             False             False          False        False
# 69             False             False          False        False
# 70             False             False          False        False
# 71             False             False          False        False
# 72             False             False          False        False
# 73             False             False          False        False
# 74             False             False          False        False
# 75             False             False           True        False
# 76             False             False          False        False
# 77             False             False          False        False
# 78             False             False          False        False
# 79             False             False          False        False
# 80             False             False          False        False
# 81             False             False          False        False
# 82             False             False          False        False
# 83             False             False          False        False
# 84             False             False          False        False
# 85             False             False          False        False
# 86             False             False           True        False
# 87             False             False          False        False
# 88             False             False          False        False
# 89             False             False          False        False
# 90             False             False          False        False
# 91             False             False          False        False
# 92             False             False          False        False
# 93             False             False          False        False
# 94             False             False          False        False
# ...              ...               ...            ...          ...
# 3326544        False             False          False        False
# 3326545        False             False          False        False
# 3326546        False             False          False        False
# 3326547        False             False          False        False
# 3326548        False             False          False        False
# 3326549        False             False          False        False
# 3326550        False             False          False        False
# 3326551        False             False          False        False
# 3326552        False             False          False        False
# 3326553        False             False           True        False
# 3326554        False             False          False        False
# 3326555        False             False          False        False
# 3326556        False             False          False        False
# 3326557        False             False          False        False
# 3326558        False             False          False        False
# 3326559        False             False          False        False
# 3326560        False             False          False        False
# 3326561        False             False          False        False
# 3326562        False             False          False        False
# 3326563        False             False          False        False
# 3326564        False             False          False        False
# 3326565        False             False          False        False
# 3326566        False             False          False        False
# 3326567        False             False          False        False
# 3326568        False             False          False        False
# 3326569        False             False          False        False
# 3326570        False             False          False        False
# 3326571        False             False          False        False
# 3326572        False             False          False        False
# 3326573        False             False          False        False
#
#          first_proposition  first_capital  first_bold  \
# 65                   False          False       False
# 66                   False          False       False
# 67                   False          False       False
# 68                   False          False       False
# 69                   False          False       False
# 70                   False          False       False
# 71                   False          False       False
# 72                   False          False       False
# 73                   False          False       False
# 74                   False          False       False
# 75                   False           True        True
# 76                   False          False       False
# 77                   False          False       False
# 78                   False           True       False
# 79                   False          False       False
# 80                   False          False       False
# 81                   False           True       False
# 82                   False          False       False
# 83                   False           True       False
# 84                   False          False       False
# 85                   False          False       False
# 86                   False           True        True
# 87                   False          False       False
# 88                   False           True       False
# 89                   False          False       False
# 90                   False          False       False
# 91                   False          False       False
# 92                   False          False       False
# 93                   False          False       False
# 94                   False           True       False
# ...                    ...            ...         ...
# 3326544              False          False       False
# 3326545              False          False       False
# 3326546              False           True       False
# 3326547              False          False       False
# 3326548              False          False       False
# 3326549              False          False       False
# 3326550              False          False       False
# 3326551              False          False       False
# 3326552              False           True       False
# 3326553              False           True        True
# 3326554              False           True       False
# 3326555              False          False       False
# 3326556              False          False       False
# 3326557              False          False       False
# 3326558              False          False       False
# 3326559              False          False       False
# 3326560              False          False       False
# 3326561              False           True       False
# 3326562              False          False       False
# 3326563              False          False       False
# 3326564              False           True       False
# 3326565              False          False       False
# 3326566              False          False       False
# 3326567              False          False       False
# 3326568              False          False       False
# 3326569              False          False       False
# 3326570              False          False       False
# 3326571              False          False       False
# 3326572              False           True       False
# 3326573              False          False       False
#
#                                                       text       kind  result  \
# 65                              = i x i c i mod 2, we call          O     NaN
# 66       this extended decision tree a parity decision ...          O     NaN
# 67       as the parity decision tree complexity, denote...          O     NaN
# 68       deﬁned in [?], which derived some simple prope...          O     NaN
# 69                            certiﬁcate complexities, C 0          O     NaN
# 70                                             ⊕ (f ), C 1          O     NaN
# 71       ⊕ (f ), and C ⊕ (f ), can be deﬁned in analogy...          O     NaN
# 72       certiﬁcate complexities (see Deﬁnition 2.1 ). ...          O     NaN
# 73       parity decision tree complexities of f (or 1 −...          O     NaN
# 74                                                to (1 ).          O     NaN
# 75       Theorem 1.1. For any Boolean function f , D ⊕ ...  B-Theorem     1.0
# 76                                               ⊕ (f )C 1  I-Theorem     1.0
# 77                                                 ⊕ (f ).  I-Theorem     1.0
# 78       The block-sensitivity of f , bs(f ), is the sm...          O     NaN
# 79       x ∈ {0, 1} n there are k pair-wise disjoint su...          O     NaN
# 80       bits in any of those subsets ﬂips f (x). Nisan...          O     NaN
# 81                                      C(f ) ≤ bs 2 (f ).          O     NaN
# 82                                                     (2)          O     NaN
# 83       Together with the simple relation that bs(f ) ...          O     NaN
# 84       is polynomially related with C(f ), thus with ...          O     NaN
# 85       the parity block sensitivity bs ⊕ (f ), and sh...          O     NaN
# 86       Theorem 1.2. For any Boolean function f , bs ⊕...  B-Theorem     2.0
# 87                                                 ⊕ (f ).  I-Theorem     2.0
# 88       The above three classes of parity complexities...          O     NaN
# 89       symmetry properties. Let c ∈ {0, 1} n . The fu...          O     NaN
# 90       f c : x → f (x + c). Let A be a linear transfo...          O     NaN
# 91       linear space over the ﬁeld F 2 ), f A is the f...          O     NaN
# 92                                                       2          O     NaN
# 93       coset H of {0, 1} n (i.e. a shift of a subspac...          O     NaN
# 94       H. A complexity measure Θ deﬁned on Boolean fu...          O     NaN
# ...                                                    ...        ...     ...
# 3326544                                                  n          O     NaN
# 3326545                         (x 1 , . . . , x n ) = sup          O     NaN
# 3326546                                                C∈C          O     NaN
# 3326547                                                  1          O     NaN
# 3326548                                                  n          O     NaN
# 3326549                                                  n          O     NaN
# 3326550                                1 C (x i ) − P(C) .          O     NaN
# 3326551                                                i=1          O     NaN
# 3326552  As a consequence of Theorem 1 we will obtain t...          O     NaN
# 3326553  Theorem 3. Let (X, X , P) be a probability spa...  B-Theorem     4.0
# 3326554  X . Then for every given ε ∈ (0, 1) there exis...  I-Theorem     4.0
# 3326555                                          such that  I-Theorem     4.0
# 3326556                                                (5)  I-Theorem     4.0
# 3326557                                                n ≤  I-Theorem     4.0
# 3326558                                       2576d(1 + ε)  I-Theorem     4.0
# 3326559                                                ε 2  I-Theorem     4.0
# 3326560                                                and  I-Theorem     4.0
# 3326561                                            D (C,P)  I-Theorem     4.0
# 3326562                                                  n  I-Theorem     4.0
# 3326563                          (x 1 , . . . , x n ) ≤ ε.  I-Theorem     4.0
# 3326564  Remark 1: This result, together with a variant...          O     NaN
# 3326565  gration is feasible even in the high-dimension...          O     NaN
# 3326566  measures. Such a general version of discrepanc...          O     NaN
# 3326567  and [?]. Note that discrepancies are usually d...          O     NaN
# 3326568  sets, such as the class A in deﬁnition (4). Ho...          O     NaN
# 3326569  class by a countable class without changing th...          O     NaN
# 3326570  may replace the class A by the subclass of tho...          O     NaN
# 3326571                                      coordinates).          O     NaN
# 3326572  Remark 2: While Theorem 3 needs to be translat...          O     NaN
# 3326573  cal integration by means of a Koksma–Hlawka in...          O     NaN
#
#                from
# 65        1004.0436
# 66        1004.0436
# 67        1004.0436
# 68        1004.0436
# 69        1004.0436
# 70        1004.0436
# 71        1004.0436
# 72        1004.0436
# 73        1004.0436
# 74        1004.0436
# 75        1004.0436
# 76        1004.0436
# 77        1004.0436
# 78        1004.0436
# 79        1004.0436
# 80        1004.0436
# 81        1004.0436
# 82        1004.0436
# 83        1004.0436
# 84        1004.0436
# 85        1004.0436
# 86        1004.0436
# 87        1004.0436
# 88        1004.0436
# 89        1004.0436
# 90        1004.0436
# 91        1004.0436
# 92        1004.0436
# 93        1004.0436
# 94        1004.0436
# ...             ...
# 3326544  1504.00143
# 3326545  1504.00143
# 3326546  1504.00143
# 3326547  1504.00143
# 3326548  1504.00143
# 3326549  1504.00143
# 3326550  1504.00143
# 3326551  1504.00143
# 3326552  1504.00143
# 3326553  1504.00143
# 3326554  1504.00143
# 3326555  1504.00143
# 3326556  1504.00143
# 3326557  1504.00143
# 3326558  1504.00143
# 3326559  1504.00143
# 3326560  1504.00143
# 3326561  1504.00143
# 3326562  1504.00143
# 3326563  1504.00143
# 3326564  1504.00143
# 3326565  1504.00143
# 3326566  1504.00143
# 3326567  1504.00143
# 3326568  1504.00143
# 3326569  1504.00143
# 3326570  1504.00143
# 3326571  1504.00143
# 3326572  1504.00143
# 3326573  1504.00143
#
# [374745 rows x 17 columns]
# /home/lucas/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# O    287085
# I     70980
# B     16680
# Name: kind, dtype: int64

# %%
filtered_dataset
# Out:
#          delta_v  delta_h  mean_length  mean_math  mean_italic  mean_fontsize  \
# 15        3.9817    0.000     5.692308   0.000000     0.000000      10.909000
# 19        3.9817    0.000     6.363636   0.000000     0.000000      10.909000
# 29        9.6880   13.353     7.818182   0.090909     0.000000       9.691273
# 75       10.1360    0.000     2.800000   0.333333     0.333333      10.517133
# 76        0.0000  270.330     1.500000   0.250000     0.000000       9.439500
# 77        0.0000  300.211     1.666667   0.333333     0.000000       9.929333
# 86        8.6069    0.000     2.500000   0.300000     0.350000      10.468150
# 87        0.0000  316.885     1.666667   0.333333     0.000000       9.929333
# 121       0.0000    0.000     3.000000   0.000000     0.000000       7.970000
# 125       3.9817    0.000     5.833333   0.000000     0.000000      10.909000
# 128      10.6537    0.000     3.368421   0.368421     0.368421      10.599632
# 129       4.8342    0.000     1.812500   0.500000     0.062500      10.174250
# 164       3.9827    0.000     4.125000   0.000000     0.000000      10.909000
# 208       0.0000    0.000     3.000000   0.000000     0.000000       7.970000
# 266       0.0000    0.000     2.500000   0.500000     0.000000      10.174250
# 278       7.8062   16.364     4.285714   0.071429     0.000000      10.699071
# 284       0.0000    0.000     1.000000   1.000000     0.000000       7.970000
# 308       2.9159    0.000     3.789474   0.315789     0.000000      10.754316
# 338      13.6017    0.000     5.250000   0.000000     0.000000      10.909000
# 373       4.8679    0.000     3.000000   0.428571     0.000000      10.489143
# 398       2.8639    0.000     2.842105   0.157895     0.000000      10.754316
# 416       8.8700    0.000     2.380952   0.380952     0.190476      10.629095
# 417       0.0000  340.013     1.800000   0.400000     0.000000      10.321200
# 419      12.9157    0.000     4.176471   0.117647     0.058824      10.909000
# 428       0.0000  132.950     1.400000   0.400000     0.000000      10.321200
# 563      14.1179    0.000     5.000000   0.000000     0.000000      10.909000
# 574       3.9817    0.000     6.583333   0.000000     0.000000      10.909000
# 623       3.9817   16.936     4.812500   0.062500     0.000000      10.909000
# 643       2.8639    0.000     6.384615   0.000000     0.000000      10.909000
# 674       3.9487    0.000     4.571429   0.000000     0.000000      10.909000
# ...          ...      ...          ...        ...          ...            ...
# 3326476   0.0000   13.488     1.000000   1.000000     0.000000       9.963000
# 3326477   0.0000   21.790     2.250000   0.250000     0.000000       9.963000
# 3326478   0.0000   88.165     1.000000   1.000000     0.000000       9.963000
# 3326479   0.0000   96.467     2.000000   0.714286     0.000000       9.536000
# 3326480  10.6628    0.000     3.800000   0.200000     0.800000       9.963000
# 3326492   1.7498    0.000     3.000000   0.500000     0.000000       5.977500
# 3326504   0.0000  117.139     1.230769   0.538462     0.000000       9.273231
# 3326553   9.7528    0.000     3.571429   0.190476     0.666667       9.963000
# 3326554   2.6600    0.000     2.857143   0.428571     0.464286       9.749500
# 3326555   2.3026    0.000     4.000000   0.000000     1.000000       9.963000
# 3326556  11.6829    0.000     3.000000   0.000000     0.000000       9.963000
# 3326557   0.0000  173.341     1.000000   1.000000     0.000000       9.963000
# 3326558   0.0000  193.800     3.333333   0.333333     0.000000       9.963000
# 3326559   3.9988  216.574     1.000000   0.500000     0.000000       8.468500
# 3326560   5.2268    0.000     3.000000   0.000000     1.000000       9.963000
# 3326561   2.1718  162.292     3.000000   0.500000     0.000000       8.468500
# 3326562   0.0000    0.000     1.000000   1.000000     0.000000       6.974000
# 3326563   0.0000    0.000     1.166667   0.750000     0.000000       9.464833
# 3326575   3.2178    0.000     5.187500   0.000000     0.000000       9.963000
# 3326586   1.6433    0.000     3.850000   0.100000     0.000000       9.664100
# 3326622   0.0000    0.000     1.000000   1.000000     0.000000       9.963000
# 3326672   0.0000   33.413     3.000000   0.000000     0.000000       9.963000
# 3326718   4.8368    0.000     4.000000   0.000000     0.000000       9.963000
# 3326727   2.6603    0.000     4.823529   0.058824     0.941176       9.963000
# 3326735  13.4318    0.000     2.062500   0.500000     0.437500       9.963000
# 3326777   7.9878    0.000     4.750000   0.125000     0.000000       9.963000
# 3326799  10.1398    0.000     4.866667   0.000000     0.000000       9.963000
# 3326803   1.7448    0.000     1.500000   1.000000     0.000000       6.974000
# 3326804   0.0000    0.000     2.000000   0.400000     0.000000       8.767400
# 3326858   0.0000  187.776     1.000000   0.000000     0.000000       9.963000
#
#          first_proof  first_definition  first_theorem  first_lemma  \
# 15             False             False          False        False
# 19             False             False          False        False
# 29             False             False          False        False
# 75             False             False           True        False
# 76             False             False          False        False
# 77             False             False          False        False
# 86             False             False           True        False
# 87             False             False          False        False
# 121            False             False          False        False
# 125            False             False          False        False
# 128            False             False           True        False
# 129            False             False          False        False
# 164            False             False          False        False
# 208            False             False          False        False
# 266            False             False          False        False
# 278            False             False          False        False
# 284            False             False          False        False
# 308            False             False          False        False
# 338            False             False          False        False
# 373            False             False          False        False
# 398            False             False          False        False
# 416            False             False           True        False
# 417            False             False          False        False
# 419            False             False          False        False
# 428            False             False          False        False
# 563            False             False          False        False
# 574            False             False          False        False
# 623            False             False          False        False
# 643            False             False          False        False
# 674            False             False          False        False
# ...              ...               ...            ...          ...
# 3326476        False             False          False        False
# 3326477        False             False          False        False
# 3326478        False             False          False        False
# 3326479        False             False          False        False
# 3326480        False             False          False        False
# 3326492        False             False          False        False
# 3326504        False             False          False        False
# 3326553        False             False           True        False
# 3326554        False             False          False        False
# 3326555        False             False          False        False
# 3326556        False             False          False        False
# 3326557        False             False          False        False
# 3326558        False             False          False        False
# 3326559        False             False          False        False
# 3326560        False             False          False        False
# 3326561        False             False          False        False
# 3326562        False             False          False        False
# 3326563        False             False          False        False
# 3326575        False             False          False        False
# 3326586        False             False          False        False
# 3326622        False             False          False        False
# 3326672        False             False          False        False
# 3326718        False             False          False        False
# 3326727        False             False          False        False
# 3326735        False             False          False        False
# 3326777        False             False          False        False
# 3326799        False             False          False        False
# 3326803        False             False          False        False
# 3326804        False             False          False        False
# 3326858        False             False          False        False
#
#          first_proposition  first_capital  first_bold  \
# 15                   False          False       False
# 19                   False          False       False
# 29                   False          False       False
# 75                   False           True        True
# 76                   False          False       False
# 77                   False          False       False
# 86                   False           True        True
# 87                   False          False       False
# 121                  False          False       False
# 125                  False          False       False
# 128                  False           True        True
# 129                  False           True       False
# 164                  False          False       False
# 208                  False          False       False
# 266                  False          False       False
# 278                  False           True       False
# 284                  False           True       False
# 308                  False          False       False
# 338                  False           True       False
# 373                  False          False       False
# 398                  False          False       False
# 416                  False           True        True
# 417                  False          False       False
# 419                  False           True        True
# 428                  False           True       False
# 563                  False           True       False
# 574                  False          False       False
# 623                  False           True       False
# 643                  False          False       False
# 674                  False          False       False
# ...                    ...            ...         ...
# 3326476              False          False       False
# 3326477              False          False       False
# 3326478              False          False       False
# 3326479              False          False       False
# 3326480              False          False       False
# 3326492              False          False       False
# 3326504              False          False       False
# 3326553              False           True        True
# 3326554              False           True       False
# 3326555              False          False       False
# 3326556              False          False       False
# 3326557              False          False       False
# 3326558              False          False       False
# 3326559              False          False       False
# 3326560              False          False       False
# 3326561              False           True       False
# 3326562              False          False       False
# 3326563              False          False       False
# 3326575              False          False       False
# 3326586              False          False       False
# 3326622              False          False       False
# 3326672              False          False       False
# 3326718              False          False       False
# 3326727              False          False       False
# 3326735              False          False       False
# 3326777              False          False       False
# 3326799              False           True       False
# 3326803              False          False       False
# 3326804              False           True       False
# 3326858              False          False       False
#
#                                                       text kind  result  \
# 15       further study parity decision trees in their r...    O     NaN
# 19       ever, capable of capturing the inherent comple...    O     NaN
# 29       ∗ Email:zhang@itcs.tsinghua.edu.cn. Supported ...    O     NaN
# 75       Theorem 1.1. For any Boolean function f , D ⊕ ...    B     1.0
# 76                                               ⊕ (f )C 1    I     1.0
# 77                                                 ⊕ (f ).    I     1.0
# 86       Theorem 1.2. For any Boolean function f , bs ⊕...    B     2.0
# 87                                                 ⊕ (f ).    I     2.0
# 121                                                    def    O     NaN
# 125      invariant version of the corresponding classic...    O     NaN
# 128      Theorem 1.3. For inﬁnitely many n, there exist...    B     3.0
# 129           D ⊕ (f n ) = O(log n) and D I (f n ) = Θ(n).    I     3.0
# 164      measures how many linear constraints have to b...    O     NaN
# 208                                                    def    O     NaN
# 266                                          wbs ⊕ (f, x).    O     7.0
# 278      We modify wbs ⊕ to a parity complexity measure...    O     NaN
# 284                                                      H    O     9.0
# 308      ..., S b ⊆ {1, 2, ..., n} be a collection of d...    O     NaN
# 338      We will need the following lemma to lower boun...    O     NaN
# 373                            query x, s t is the output.    O     NaN
# 398      decision tree complexity of these f is no more...    O     NaN
# 416      Theorem 5.1. For any XOR function F (x, y) = f...    B    12.0
# 417                                          ⊕ (f ) log n.    I    12.0
# 419      Deﬁnition 5.2. A set C of 1-parity certiﬁcates...    O    13.0
# 428                                            Let d = C 1    O     NaN
# 563      The Isolation Lemma by Mulmuley, Vazirani, and...    O     NaN
# 574      derandomized. In particular, it will give a de...    O     NaN
# 623      Since our condition on the polytope P (B) does...    O     NaN
# 643      quasi-polynomially bounded weights; see Theore...    O     NaN
# 674                 in the context of optimization [?, ?].    O     NaN
# ...                                                    ...  ...     ...
# 3326476                                                  √    I     3.0
# 3326477                                       n + 58000d +    I     3.0
# 3326478                                                  √    I     3.0
# 3326479                               8nx + κ(η)x ≤ e −x ,    I     3.0
# 3326480                            where κ(η) is as above.    I     3.0
# 3326492                                            [0,1] d    O     NaN
# 3326504                       n (x 1 , . . . , x n ) = sup    O     NaN
# 3326553  Theorem 3. Let (X, X , P) be a probability spa...    B     4.0
# 3326554  X . Then for every given ε ∈ (0, 1) there exis...    I     4.0
# 3326555                                          such that    I     4.0
# 3326556                                                (5)    I     4.0
# 3326557                                                n ≤    I     4.0
# 3326558                                       2576d(1 + ε)    I     4.0
# 3326559                                                ε 2    I     4.0
# 3326560                                                and    I     4.0
# 3326561                                            D (C,P)    I     4.0
# 3326562                                                  n    I     4.0
# 3326563                          (x 1 , . . . , x n ) ≤ ε.    I     4.0
# 3326575  direct application of Theorem 2 it would be ne...    O     NaN
# 3326586  2 26 dε −2 . In other words, the result in The...    O     NaN
# 3326622                                                  √    O     5.0
# 3326672                                                for    O     NaN
# 3326718                                               914d    O     7.0
# 3326727  absolute values are uniformly bounded by a con...    O     8.0
# 3326735   for some A > e and v ≥ 2. Let σ ≤ U be such that    O     8.0
# 3326777  for every δ > 0. By a well-known relation betw...    O     NaN
# 3326799  From a combination of Lemma 4 and Lemma 6 we d...    O     NaN
# 3326803                                               f ∈F    O    11.0
# 3326804                                     E(f 2 (ξ i )),    O    11.0
# 3326858                                                  +    O     NaN
#
#                from
# 15        1004.0436
# 19        1004.0436
# 29        1004.0436
# 75        1004.0436
# 76        1004.0436
# 77        1004.0436
# 86        1004.0436
# 87        1004.0436
# 121       1004.0436
# 125       1004.0436
# 128       1004.0436
# 129       1004.0436
# 164       1004.0436
# 208       1004.0436
# 266       1004.0436
# 278       1004.0436
# 284       1004.0436
# 308       1004.0436
# 338       1004.0436
# 373       1004.0436
# 398       1004.0436
# 416       1004.0436
# 417       1004.0436
# 419       1004.0436
# 428       1004.0436
# 563      1708.02222
# 574      1708.02222
# 623      1708.02222
# 643      1708.02222
# 674      1708.02222
# ...             ...
# 3326476  1504.00143
# 3326477  1504.00143
# 3326478  1504.00143
# 3326479  1504.00143
# 3326480  1504.00143
# 3326492  1504.00143
# 3326504  1504.00143
# 3326553  1504.00143
# 3326554  1504.00143
# 3326555  1504.00143
# 3326556  1504.00143
# 3326557  1504.00143
# 3326558  1504.00143
# 3326559  1504.00143
# 3326560  1504.00143
# 3326561  1504.00143
# 3326562  1504.00143
# 3326563  1504.00143
# 3326575  1504.00143
# 3326586  1504.00143
# 3326622  1504.00143
# 3326672  1504.00143
# 3326718  1504.00143
# 3326727  1504.00143
# 3326735  1504.00143
# 3326777  1504.00143
# 3326799  1504.00143
# 3326803  1504.00143
# 3326804  1504.00143
# 3326858  1504.00143
#
# [175320 rows x 17 columns]

# %%
dataset[['mean_math', 'text', 'from']].iloc[9:200]
# Out:
#      mean_math                                               text       from
# 9     0.000000                                           Abstract  1004.0436
# 10    0.000000  The parity decision tree model extends the dec...  1004.0436
# 11    0.000000  computation of a parity function in one step. ...  1004.0436
# 12    0.000000  parity decision tree complexity of any Boolean...  1004.0436
# 13    0.000000  the non-deterministic complexity of the functi...  1004.0436
# 14    0.000000  that they are polynomially related to an analo...  1004.0436
# 15    0.000000  further study parity decision trees in their r...  1004.0436
# 16    0.000000  the decision trees, as well as with communicat...  1004.0436
# 17    0.000000              1 Introduction and summary of results  1004.0436
# 18    0.000000  The decision tree model is perhaps the simples...  1004.0436
# 19    0.000000  ever, capable of capturing the inherent comple...  1004.0436
# 20    0.000000  problems. Its relations with other models of c...  1004.0436
# 21    0.000000  useful. In this section, we will ﬁrst review s...  1004.0436
# 22    0.000000  decision trees, before we present a summary of...  1004.0436
# 23    0.294118  Let f : {0, 1} n → {0, 1} be a Boolean functio...  1004.0436
# 24    0.076923  speciﬁed otherwise. Formally, a decision tree ...  1004.0436
# 25    0.062500  binary tree T , labeled as follows: (1) each n...  1004.0436
# 26    0.250000  i ∈ {1, 2, ..., n} to the input bits, (2) each...  1004.0436
# 27    0.250000  0 or 1. The computation of T on an input x ∈ {...  1004.0436
# 28    0.166667  at the root and follows the x i edge from a ve...  1004.0436
# 29    0.090909  ∗ Email:zhang@itcs.tsinghua.edu.cn. Supported ...  1004.0436
# 30    0.000000  of China Grant 60553001, and the National Basi...  1004.0436
# 31    0.000000                                      2007CB807901.  1004.0436
# 32    0.076923  † Email:shiyy@eecs.umich.edu. Supported in par...  1004.0436
# 33    0.000000              under the grants 0347078 and 0622033.  1004.0436
# 34    0.000000                                                  1  1004.0436
# 35    0.105263  reached by this path is the output of T on x. ...  1004.0436
# 36    0.076923  complexity of the algorithm. The minimum depth...  1004.0436
# 37    0.153846  is the deterministic decision tree complexity ...  1004.0436
# 38    0.142857  A set of decision trees non-deterministically ...  1004.0436
# ..         ...                                                ...        ...
# 170   0.437500   of f , denoted by C ⊕ (f ), is max x C ⊕ (f, x).  1004.0436
# 171   0.142857  A parity certiﬁcate S is called a 0- (or 1-) p...  1004.0436
# 172   0.294118  1, respectively) for all x ∈ S ∩D. The 0- and ...  1004.0436
# 173   0.500000                                                C 0  1004.0436
# 174   0.333333                                             ⊕ (f )  1004.0436
# 175   0.000000                                                def  1004.0436
# 176   0.454545                = max x:f (x)=0 C ⊕ (f, x), and C 1  1004.0436
# 177   0.333333                                             ⊕ (f )  1004.0436
# 178   0.000000                                                def  1004.0436
# 179   0.444444          = max x:f (x)=1 C ⊕ (f, x), respectively.  1004.0436
# 180   0.454545                      If f ≡ 0 (or f ≡ 1), then C 1  1004.0436
# 181   0.333333                                     ⊕ (f ) (or C 0  1004.0436
# 182   0.111111        ⊕ (f ), respectively) is not deﬁned. We may  1004.0436
# 183   0.210526  represent a parity certiﬁcate S of size T (or ...  1004.0436
# 184   0.518519  (C, r), where C ∈ {0, 1} T ×n and r ∈ {0, 1} T...  1004.0436
# 185   0.266667  from the deﬁnitions that when B ∈ {0, 1} n×n t...  1004.0436
# 186   0.500000                                   C ⊕ (f, x) = min  1004.0436
# 187   1.000000                                                  B  1004.0436
# 188   1.000000                                   C(f B , B −1 x).  1004.0436
# 189   0.000000                                                (5)  1004.0436
# 190   0.000000  Similar relations between the 0- and 1-parity ...  1004.0436
# 191   0.000000  that 0- and 1-parity certiﬁcate complexity mea...  1004.0436
# 192   0.214286  decision tree complexity of f and 1 − f , resp...  1004.0436
# 193   0.000000  parity decision tree complexity deﬁned in anal...  1004.0436
# 194   0.000000  tree complexity. Since any parity decision tre...  1004.0436
# 195   0.000000  than the depth of the tree for any input, we h...  1004.0436
# 196   0.352941  Proposition 2.2. For any Boolean function f , ...  1004.0436
# 197   0.250000  We now prove Theorem 1.1 , which states that D...  1004.0436
# 198   0.250000                                          ⊕ (f )C 1  1004.0436
# 199   0.200000                                    ⊕ (f ), for any  1004.0436
#
# [191 rows x 3 columns]

# %%
n_train = 2100
n_test  = 600
np.random.shuffle(papers)
papers_train = papers[:n_train]
papers_test  = papers[n_train:n_train + n_test]

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV

# Set the parameters of the model
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
        
    c1 = 0.000,
    c2 = 0.000,
    
    max_iterations=100,
    
    # whether to include transitions that
    # are possible, but not observed
    all_possible_transitions=False
)

# %%
def get_features(paper):
    global filtered_dataset
    
    data = filtered_dataset[filtered_dataset['from']==paper]
    X_features = data.drop(['from', 'text', 'kind', 'result'], axis=1)
    X_mean = X_features.rolling(64, min_periods=1, center=True).mean()
    X_std  = X_features.rolling(64, min_periods=1, center=True).std()
    
    numeric_cols = ['delta_v', 'delta_h', 'mean_length', 'mean_math', 'mean_italic',
       'mean_fontsize']
    X_features[numeric_cols] = ((X_features - X_mean)/(X_std + 1e-12))[numeric_cols]
        
        
    boolean_cols = ['first_proof', 'first_definition', 'first_theorem',
       'first_lemma', 'first_proposition', 'first_capital', 'first_bold']
    X_features[boolean_cols] = 2*X_features[boolean_cols] - 1
    
    X_features = X_features.to_dict('records')
    
    if len(X_features) == 0:
        return [], []
    keys = X_features[0].keys()
    
    X = []
    
    for i, entry in enumerate(X_features):
        sample = {}
        for key in keys:
            prec_value = X_features[i-1][key] if i > 0 else 0
            value = entry[key]
            next_value = X_features[i+1][key] if i < len(X_features)-1 else 0
            
            sample["value_"+key] = value
            sample["prec_"+key]  = prec_value - value
            sample["next_"+key]  = next_value - value
        X.append(sample)
    
    y = list(data['kind'])
    return X,y

# %%
from tqdm.notebook import tqdm


X,y = zip(*[get_features(paper) for paper in tqdm(papers_train)])
# Out:
# HBox(children=(IntProgress(value=0, max=2100), HTML(value='')))

# %%
crf.fit(X, y)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=0.0, c2=0.0, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
X_test,y_test = zip(*[get_features(paper) for paper in tqdm(papers_test)])
# Out:
# HBox(children=(IntProgress(value=0, max=542), HTML(value='')))

# %%
y_pred_train = crf.predict(X)
y_pred_test = crf.predict(X_test)

# %%
print("Train")
print(metrics.flat_classification_report(y, y_pred_train, digits=2))
print("Test")
print(metrics.flat_classification_report(y_test, y_pred_test, digits=2))
# Out:
# Train
#               precision    recall  f1-score   support
#
#            B       0.96      0.95      0.96     13368
#            I       0.84      0.70      0.76     57424
#            O       0.93      0.96      0.94    229342
#
#     accuracy                           0.91    300134
#    macro avg       0.91      0.87      0.89    300134
# weighted avg       0.91      0.91      0.91    300134
#
# Test
#               precision    recall  f1-score   support
#
#            B       0.96      0.96      0.96      3312
#            I       0.83      0.73      0.78     13556
#            O       0.94      0.96      0.95     57743
#
#     accuracy                           0.92     74611
#    macro avg       0.91      0.89      0.90     74611
# weighted avg       0.92      0.92      0.92     74611

# %%
import eli5
eli5.show_weights(crf, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>B</th>
#
#                 <th>I</th>
#
#                 <th>O</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>B</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.58%)" title="B &rArr; B">
#                             -2.427
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.70%)" title="B &rArr; I">
#                             1.12
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.63%)" title="B &rArr; O">
#                             -0.728
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 83.14%)" title="I &rArr; B">
#                             -1.982
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.93%)" title="I &rArr; I">
#                             2.189
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.07%)" title="I &rArr; O">
#                             -0.248
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.17%)" title="O &rArr; B">
#                             2.148
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.00%)" title="O &rArr; I">
#                             -2.53
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.40%)" title="O &rArr; O">
#                             2.459
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.551
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_first_theorem
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.535
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_first_capital
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.095
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         next_first_proof
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.901
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_first_bold
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.838
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_mean_italic
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.610
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_mean_length
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.363
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         prec_first_proposition
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.288
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         value_delta_v
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.197
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         prec_mean_length
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.168
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         prec_first_lemma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.047
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         prec_mean_fontsize
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.040
#     </td>
#     <td style="padding: 0 0.5em 0 0.5

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

y_pred_test_ok = [x for y in y_pred_test for x in y]
y_test_ok      = [x for y in y_test for x in y]
labels         = sorted(list(set(y_test_ok)))
mtx = confusion_matrix(y_pred_test_ok, y_test_ok, labels)

df_cm = pd.DataFrame(mtx, index = labels,
                  columns = labels)

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

# %% [markdown]
# # Error exploration

# %%
c = 0
    
for i, paper in enumerate(tqdm(papers_test)):
    pred = y_pred_test[i]
    true = y_test[i]
    
    for j,(a,b) in list(enumerate(zip(pred, true))):
        if (a == 'I' and b == 'O') or (a == 'O' and b == 'I'):
            c += 1
            entry = filtered_dataset[filtered_dataset['from']==paper].iloc[j]
            just_before = filtered_dataset[filtered_dataset['from']==paper].iloc[j-1]
            text = entry['text']
            result = entry['result']
            print(f"[{paper}] {a} instead of {b}: {text} ({result})")
            print(f"Context: ", just_before['text'], " (", just_before['result'], ")", sep="")
            #print(X_test[i])
            print("##")
    if c > 30:
        break
# Out:
# HBox(children=(IntProgress(value=0, max=542), HTML(value='')))
# [1607.05133] I instead of O: 1. Find C ⊆ V \ {s, t} such that |C| ≤ Ω(l) · |C ∗ | and dist(G \ C) ≥ l. (nan)
# Context: it is NP-hard to perform any of the following tasks. (3.0)
# ##
# [1607.05133] I instead of O: 2. Find C ⊆ V \ {s, t} such that |C| ≤ |C ∗ | and dist(G \ C) ≥ O( (nan)
# Context: 1. Find C ⊆ V \ {s, t} such that |C| ≤ Ω(l) · |C ∗ | and dist(G \ C) ≥ l. (nan)
# ##
# [1607.05133] I instead of O: 3. Find C ⊆ V \ {s, t} such that |C| ≤ Ω(l 2 ) · |C ∗ | and dist(G \ C) ≥ O(l (nan)
# Context: l). (3.0)
# ##
# [1607.05133] I instead of O: 1. Find C ⊆ E such that |C| ≤ Ω( (nan)
# Context: it is NP-hard to perform any of the following tasks. (4.0)
# ##
# [1607.05133] I instead of O: 2. Find C ⊆ E such that |C| ≤ |C ∗ | and dist(G \ C) ≥ l (nan)
# Context: l) · |C ∗ | and dist(G \ C) ≥ l. (4.0)
# ##
# [1607.05133] I instead of O: 3. Find C ⊆ E such that |C| ≤ Ω(l (nan)
# Context: 3 . (4.0)
# ##
# [1509.05623] I instead of O: This allows to settle the case of D 1 =< maj, x + y + z > and of the two (nan)
# Context: set of indices I of size k − 1, v I ∈ Cl F (S) I . (2.0)
# ##
# [1509.05623] I instead of O: inﬁnite families of clones of our restricted lattice S k (nan)
# Context: This allows to settle the case of D 1 =< maj, x + y + z > and of the two (nan)
# ##
# [1509.05623] I instead of O: 10 =< T h k+1 (nan)
# Context: inﬁnite families of clones of our restricted lattice S k (nan)
# ##
# [1509.05623] I instead of O: k (nan)
# Context: 10 =< T h k+1 (nan)
# ##
# [1509.05623] I instead of O: , x ∧ (y ∨ z) > (nan)
# Context: k (nan)
# ##
# [1509.05623] I instead of O: and S k (nan)
# Context: , x ∧ (y ∨ z) > (nan)
# ##
# [1509.05623] I instead of O: 12 =< T h k+1 (nan)
# Context: and S k (nan)
# ##
# [1509.05623] I instead of O: k (nan)
# Context: 12 =< T h k+1 (nan)
# ##
# [1509.05623] I instead of O: , x ∧ (y → z) >. (nan)
# Context: k (nan)
# ##
# [1510.08352] O instead of I: lation problem is (4.0)
# Context: Theorem 5.3. The maximum success probability of a q-query algorithm in the polynomial interpo- (4.0)
# ##
# [1510.08352] O instead of I: |F| if q ≤ d (4.0)
# Context: 1. At most 1 (nan)
# ##
# [1510.08352] O instead of I: 2 (4.0)
# Context: |F| if q ≤ d (4.0)
# ##
# [1510.08352] O instead of I: q! 1 − q+1 (4.0)
# Context: 2. Between 1 (nan)
# ##
# [1510.08352] O instead of I: 2 (4.0)
# Context: q! 1 − q+1 (4.0)
# ##
# [1510.08352] O instead of I: 1 (4.0)
# Context: 2 (4.0)
# ##
# [1510.08352] O instead of I: |F| and 1 (4.0)
# Context: 1 (4.0)
# ##
# [1510.08352] O instead of I: q! if q = d (4.0)
# Context: |F| and 1 (4.0)
# ##
# [1510.08352] O instead of I: 2 + 1 (4.0)
# Context: q! if q = d (4.0)
# ##
# [1510.08352] O instead of I: 2 (4.0)
# Context: 2 + 1 (4.0)
# ##
# [1510.08352] O instead of I: |F| (4.0)
# Context: 3. At least 1 − (d/2+1)!+d+1 (nan)
# ##
# [1510.08352] O instead of I: if q ≥ d (4.0)
# Context: |F| (4.0)
# ##
# [1510.08352] O instead of I: 2 + 1 (4.0)
# Context: if q ≥ d (4.0)
# ##
# [1510.08352] I instead of O: 1. 1/|F| if q ≤ d/2. (nan)
# Context: 21 (6.0)
# ##
# [1510.08352] I instead of O: 2. At most (|F| − 1)/q /|F| ≈ 1/q for q = (d + 1)/2. Moreover, if q|(|F| − 1), this is tight. (nan)
# Context: 1. 1/|F| if q ≤ d/2. (nan)
# ##
# [1510.08352] I instead of O: 3. At least 1 − (d/2+1)!+d+1 (nan)
# Context: 2. At most (|F| − 1)/q /|F| ≈ 1/q for q = (d + 1)/2. Moreover, if q|(|F| − 1), this is tight. (nan)
# ##
